# %% [markdown]
# ## Compare Two Stage Q-learning

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
import mlflow
# Out:
# /opt/conda/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:199: UserWarning: Failure attempting to register store for scheme "azureml": No module named 'azureml.mlflow'
#   _tracking_store_registry.register_entrypoints()
# /opt/conda/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:115: UserWarning: Failure attempting to register artifact repository for scheme "azureml": No module named 'azureml.mlflow'
#   _artifact_repository_registry.register_entrypoints()

# %%
ml_client = MLClient.from_config(credential=DefaultAzureCredential())
mlflow_tracking_uri = ml_client.workspaces.get(ml_client.workspace_name).mlflow_tracking_uri
mlflow.set_tracking_uri(mlflow_tracking_uri)
# Out:
# Found the config file in: ./config.json
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %%
mlflow.get_experiment_by_name("Smart_Q-learning_for_SIRS")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/registry.py:81, in StoreRegistry.get_store_builder(self, store_uri)
#      80 try:
# ---> 81     store_builder = self._registry[scheme]
#      82 except KeyError:
#
# KeyError: 'azureml'
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedModelRegistryStoreURIException Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mlflow.get_experiment_by_name("Smart_Q-learning_for_SIRS")
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/fluent.py:1678, in get_experiment_by_name(name)
#    1644 def get_experiment_by_name(name: str) -> Optional[Experiment]:
#    1645     """
#    1646     Retrieve an experiment by experiment name from the backend store
#    1647
#    (...)
#    1676         Creation timestamp: 1662004217511
#    1677     """
# -> 1678     return MlflowClient().get_experiment_by_name(name)
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/client.py:133, in MlflowClient.__init__(self, tracking_uri, registry_uri)
#     131 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     132 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 133 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:83, in TrackingServiceClient.__init__(self, tracking_uri)
#      78 self.tracking_uri = tracking_uri
#      79 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      80 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      81 # property method to ensure that the client is serializable, even if the store is not
#      82 # self.store
# ---> 83 self.store
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:87, in TrackingServiceClient.store(self)
#      85 @property
#      86 def store(self):
# ---> 87     return utils._get_store(self.tracking_uri)
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:210, in _get_store(store_uri, artifact_uri)
#     209 def _get_store(store_uri=None, artifact_uri=None):
# --> 210     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/registry.py:55, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      49 """
#      50 Retrieve the store associated with a resolved (non-None) store URI and an artifact URI.
#      51 Caching is done on resolved URIs because the meaning of an unresolved (None) URI may change
#      52 depending on external configuration, such as environment variables
#      53 """
#      54 with _building_store_lock:
# ---> 55     builder = self.get_store_builder(resolved_store_uri)
#      56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File /opt/conda/lib/python3.11/site-packages/mlflow/tracking/registry.py:83, in StoreRegistry.get_store_builder(self, store_uri)
#      81     store_builder = self._registry[scheme]
#      82 except KeyError:
# ---> 83     raise UnsupportedModelRegistryStoreURIException(
#      84         unsupported_uri=store_uri, supported_uri_schemes=list(self._registry.keys())
#      85     )
#      86 return store_builder
#
# UnsupportedModelRegistryStoreURIException:  Model registry functionality is unavailable; got unsupported URI 'azureml://westeurope.api.azureml.ms/mlflow/v1.0/subscriptions/405b7c23-a502-4c7a-8b74-53e321fe3a15/resourceGroups/rg-research-pro-001/providers/Microsoft.MachineLearningServices/workspaces/mlw-research-pro-001' for model registry data storage. Supported URI schemes are: ['', 'file', 'databricks', 'databricks-uc', 'uc', 'http', 'https', 'postgresql', 'mysql', 'sqlite', 'mssql']. See https://www.mlflow.org/docs/latest/tracking.html#storage for how to run an MLflow server against one of the supported backend storage locations.

# %%
jobs_names = [
    "cyan_ship_sbszzycyph",
    "funny_pear_sczdyc4n5h",
    "sincere_ball_cs6t5wxqpc",
    "lime_orange_sfwyqgyxtm",
]
metric = "log_relative_error_mean"
experiments_K_abs = [25000, 50000, 100000, 500000]

# %%
for job_name in jobs_names:
    job = ml_client.jobs.get(job_name)

# %%
job
# Out:
# Command({'parameters': {'n_episodes': '1000000.0', 'n_steps': '1000000.0', 'alpha_max': '0.5', 'alpha_min': '0.0001', 'alpha_decay': '0.0001', 'epsilon': '0.1', 'discount_factor': '0.99', 'learn_mode': 'two_stages', 'max_steps_episode': '500', 'no_infection_learn_steps': '500000', 'state_action_values_initialization': 'random', 'log_every_n_steps': '1000', 'save_every_n_steps': '100000', 'size': '5', 'encounter_rate': '1.1', 'recovery_rate': '0.6', 'resusceptible_rate': '0.3', 'vaccination_rate': '0.2', 'cost_infection': '2', 'cost_lockdown': '1.001'}, 'init': False, 'name': 'lime_orange_sfwyqgyxtm', 'type': 'command', 'status': 'Completed', 'log_files': None, 'description': None, 'tags': {'_aml_system_ComputeTargetStatus': '{"AllocationState":"steady","PreparingNodeCount":0,"RunningNodeCount":1,"CurrentNodeCount":1}', 'Learn mode': 'two_stages'}, 'properties': {'mlflow.source.git.repoURL': 'https://github.com/ccarballolozano/epidemic-models-rl.git', 'mlflow.source.git.branch': 'feature/gym_env_sirs', 'mlflow.source.git.commit': 'd632cca11f2353c08245685573b2700a2e44cd5f', 'azureml.git.dirty': 'True', '_azureml.ComputeTargetType': 'amlctrain', '_azureml.ClusterName': 'cpu-cluster-002', 'ContentSnapshotId': '217518b9-1537-4662-b828-9e33b23484b6', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'StartTimeUtc': '2025-02-17 16:48:44', 'EndTimeUtc': '2025-02-18 05:20:15'}, 'print_as_yaml': False, 'id': '/subscriptions/405b7c23-a502-4c7a-8b74-53e321fe3a15/resourceGroups/rg-research-pro-001/providers/Microsoft.MachineLearningServices/workspaces/mlw-research-pro-001/jobs/lime_orange_sfwyqgyxtm', 'Resource__source_path': '', 'base_path': '/workspaces/epidemic-models-rl/experiments', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7fb803550b10>, 'serialize': <msrest.serialization.Serializer object at 0x7fb8035a51d0>, 'allowed_keys': {}, 'key_restriction': False, 'logger': <Logger attr_dict (WARNING)>, 'display_name': 'lime_orange_sfwyqgyxtm', 'experiment_name': 'Smart_Q-learning_for_SIRS', 'compute': 'cpu-cluster-002', 'services': {'Tracking': {'endpoint': 'azureml://westeurope.api.azureml.ms/mlflow/v1.0/subscriptions/405b7c23-a502-4c7a-8b74-53e321fe3a15/resourceGroups/rg-research-pro-001/providers/Microsoft.MachineLearningServices/workspaces/mlw-research-pro-001?', 'type': 'Tracking'}, 'Studio': {'endpoint': 'https://ml.azure.com/runs/lime_orange_sfwyqgyxtm?wsid=/subscriptions/405b7c23-a502-4c7a-8b74-53e321fe3a15/resourcegroups/rg-research-pro-001/workspaces/mlw-research-pro-001&tid=944a88f0-8401-4e30-ab9b-438f9bade44d', 'type': 'Studio'}}, 'comment': None, 'job_inputs': {}, 'job_outputs': {'default': {'type': 'uri_folder', 'path': 'azureml://datastores/workspaceartifactstore/ExperimentRun/dcid.lime_orange_sfwyqgyxtm', 'mode': 'rw_mount'}}, 'inputs': {}, 'outputs': {'default': <azure.ai.ml.entities._job.pipeline._io.base.NodeOutput object at 0x7fb8035b3410>}, 'component': CommandComponent({'latest_version': None, 'intellectual_property': None, 'auto_increment_version': True, 'source': 'REMOTE.WORKSPACE.JOB', 'is_anonymous': False, 'auto_delete_setting': None, 'name': 'lime_orange_sfwyqgyxtm', 'description': None, 'tags': {'_aml_system_ComputeTargetStatus': '{"AllocationState":"steady","PreparingNodeCount":0,"RunningNodeCount":1,"CurrentNodeCount":1}', 'Learn mode': 'two_stages'}, 'properties': {}, 'print_as_yaml': False, 'id': None, 'Resource__source_path': None, 'base_path': '/workspaces/epidemic-models-rl/experiments', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7fb803550b10>, 'serialize': <msrest.serialization.Serializer object at 0x7fb8035a7490>, 'command': 'python rl_experiment.py', 'code': '/subscriptions/405b7c23-a502-4c7a-8b74-53e321fe3a15/resourceGroups/rg-research-pro-001/providers/Microsoft.MachineLearningServices/workspaces/mlw-research-pro-001/codes/c3da4a51-1de2-4faf-8a02-ed352c3eafd7/versions/1', ' ...
